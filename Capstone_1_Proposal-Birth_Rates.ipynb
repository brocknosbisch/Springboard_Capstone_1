# %% [markdown]
# ### Predicting Future Birth Rates
# By Brock Nosbisch
# <br>
# <br>
# **What is the problem you want to solve?**
# <br>
# The problem I am trying to solve is to predict future birth rates in the United States.
#
# **Who is your client and why do they care about this problem? In other words, what will your client do or decide based on your analysis that they wouldn’t have done otherwise?**
# <br>
# My client is any company selling products for babies, toddlers, kids, etc.  Predicting future trends in birth rates will allow the companies to target kid age groups as well as target the mother's age group.  <br>
# Some examples of future trends are: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Will the birth rate increase or decrease? <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;How old will the mom be when she gives birth? <br>
#
# **What data are you using? How will you acquire the data?**
# <br>
# The data used for this project comes from the Centers for Disease Control and Prevention (CDC), Kaggle, and World Bank.  I will be manually downloading the files (in various extensions), extract the files needing extracted, and then load, parse, and clean the data in python.  There are a total of 7 datasets that I can combine but I may omit 2 because they are at a state level. <br><br>
# **Datasets:** <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Birth Rates (US): <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Age - Age Range <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Birth Rate <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Site: https://data.cdc.gov/NCHS/NCHS-Birth-Rates-for-Females-by-Age-Group-United-S/yt7u-eiyg/data
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;File: NCHS_-Birth_Rates_for_Females_by_Age_Group__United_States.csv
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Marriage Rate by State: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;State <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Marriage Rate <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Site: https://www.cdc.gov/nchs/data/dvs/state-marriage-rates-90-95-99-17.pdf
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;File: state-marriage-rates-90-95-99-17.pdf
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Divorce Rate by State: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;State <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Divorce Rate <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Site: https://www.cdc.gov/nchs/data/dvs/state-divorce-rates-90-95-99-17.pdf
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;File: state-divorce-rates-90-95-99-17.pdf
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Marriage/Divorce Rates at US level: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Total Marriages <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Total Divorces <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Population <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Rates per 1000 <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Site: https://www.cdc.gov/nchs/data/dvs/national-marriage-divorce-rates-00-17.pdf
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;File: national-marriage-divorce-rates-00-17.pdf
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Life Expectancy by Country: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Life Expectancy <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Mortality Rate (15-60) <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Infant Deaths per 1000 <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;BMI <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Under 5 Deaths <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Site: https://www.kaggle.com/kumarajarshi/life-expectancy-who#Life%20Expectancy%20Data.csv%20
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;File: Life Expectancy Data.csv
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Birth Rates by Country: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Country <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Birth Rate <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Site: https://data.worldbank.org/indicator/SP.DYN.LE00.IN?view=chart
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;File: API_SP.DYN.CBRT.IN_DS2_en_csv_v2_10402674.csv
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Life Expectancy by Country: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Year <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Country <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Life Expectancy <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Site: https://data.worldbank.org/indicator/SP.DYN.LE00.IN?view=chart
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;File: API_SP.DYN.LE00.IN_DS2_en_csv_v2_10399651.csv
#
#
#
#
# **Briefly outline how you’ll solve this problem. Your approach may change later, but this is a good first step to get you thinking about a method and solution.**
# <br>
# I will first download all files and extract the zip files.  I will then do Data Wrangling, EDA, and test different machine learning algorithms to see which best predicts the future trends.  The trends will be identified for birth rates by various combinations of YOY Birth Rate, Life Expectancy, Infant Deaths, Mortality Rate, Marriage Rate, Divorce Rate, Mother's Age at Birth, etc.
#
# **What are your deliverables? Typically, this includes code, a paper, or a slide deck.**
# <br>
# My deliverables will be a jupyter notebook and slide deck that will be published to my github account.  I will include all my findings and all documented python code.
